# %% [markdown]
# # 3 - Disponibilização da fonte
#
# A fonte de dados **foi disponibilizada dentro do Workspace**.
#
# Local:
# `Workspace > users > mario.farias1@gmail.com > MVP-Engenharia de Dados-MFarias > StudentsPerformance.xls`

# %%
SOURCE_FILE = "StudentsPerformance.xls"
WORKSPACE_FOLDER = "MVP-Engenharia de Dados-MFarias"
print("Arquivo:", SOURCE_FILE)
print("Pasta:", WORKSPACE_FOLDER)
print("Fonte previamente disponibilizada no Workspace.")
# Out:
# Arquivo: StudentsPerformance.xls
# Pasta: MVP-Engenharia de Dados-MFarias
# Fonte previamente disponibilizada no Workspace.
